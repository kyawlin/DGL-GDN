# %%
import os
from datetime import datetime
from pathlib import Path

# %%
import pandas as pd
import numpy as np
import torch
import dgl

dgl.__version__
# Out:
# Using backend: pytorch
# '0.6.1'

# %%
import random

from torch.utils.data import DataLoader, Subset
import torch.nn.functional as F
import torch.nn as nn
from Dataset import TimeDataset
from config import configs
from model import GDN

# %%
train_dataset = TimeDataset(is_train=True, config=configs)
test_dataset = TimeDataset(is_train=False, config=configs)

dataset_len = int(len(train_dataset))
train_len = int(dataset_len * (1 - configs["val_ratio"]))
val_len = dataset_len - train_len
val_start_idx = random.randrange(train_len)
indices = torch.arange(dataset_len)
train_sub_indices = torch.cat(
    [indices[:val_start_idx], indices[val_start_idx + val_len :]]
)
train_subset = Subset(train_dataset, train_sub_indices)

val_sub_indices = indices[val_start_idx : val_start_idx + val_len]
val_subset = Subset(train_dataset, val_sub_indices)

train_dataloader = DataLoader(
    train_subset, batch_size=configs["batch_size"], shuffle=True, drop_last=True
)

val_dataloader = DataLoader(
    val_subset, batch_size=configs["batch_size"], shuffle=False, drop_last=True
)
test_dataloader = DataLoader(
    test_dataset,
    batch_size=configs["batch_size"],
    shuffle=False,
    num_workers=0,
    drop_last=True,
)

# %%
graph = train_dataset.getGraph()
graph
# Out:
# Graph(num_nodes=27, num_edges=702,
#       ndata_schemes={}
#       edata_schemes={})

# %%
model = GDN(
    graph,
    embed_dim=configs["embed_dim"],
    input_dim=configs["slide_win"],
    hidden_dim=configs["hidden_dim"],
    outlayer_hidden_dim=configs["outlayer_hidden_dim"],
    num_outlayers=configs["num_outlayers"],
    topk=configs["topk"],
    dropout=configs["dropout"],
    device=configs["device"]
)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=configs['decay'])
train_loss_list = []

# %%
acu_loss = 0
min_loss = 1e+8
min_f1 = 0
min_pre = 0
best_prec = 0

# %%
def get_save_path( feature_name=""):
    
    dir_path = ""

#     if datestr is None:
    now = datetime.now()
    datestr = now.strftime("%m|%d-%H:%M:%S")
 

    paths = [
        f"./pretrained/{dir_path}/best_{datestr}.pt",
        f"./results/{dir_path}/{datestr}.csv",
    ]

    for path in paths:
        dirname = os.path.dirname(path)
        Path(dirname).mkdir(parents=True, exist_ok=True)

    return paths

# %%
def test(model, dataloader):
    # test
    loss_func = nn.MSELoss(reduction='mean')
    device = "cpu"

    test_loss_list = []
#     now = time.time()

    test_predicted_list = []
    test_ground_list = []
    test_labels_list = []

    t_test_predicted_list = []
    t_test_ground_list = []
    t_test_labels_list = []

    test_len = len(dataloader)

    model.eval()

    i = 0
    acu_loss = 0
    for x, y, labels  in dataloader:
        x, y, labels = [item.to(device).float() for item in [x, y, labels]]
        
        with torch.no_grad():
            predicted = model(x).float().to(device)
            print (predicted.shape,y.shape,x.shape)
            
            loss = loss_func(predicted, y)
            

            labels = labels.unsqueeze(1).repeat(1, predicted.shape[1])

            if len(t_test_predicted_list) <= 0:
                t_test_predicted_list = predicted
                t_test_ground_list = y
                t_test_labels_list = labels
            else:
                t_test_predicted_list = torch.cat((t_test_predicted_list, predicted), dim=0)
                t_test_ground_list = torch.cat((t_test_ground_list, y), dim=0)
                t_test_labels_list = torch.cat((t_test_labels_list, labels), dim=0)
        
        test_loss_list.append(loss.item())
        acu_loss += loss.item()
        
        i += 1

#         if i % 10000 == 1 and i > 1:
#             print(timeSincePlus(now, i / test_len))


    test_predicted_list = t_test_predicted_list.tolist()        
    test_ground_list = t_test_ground_list.tolist()        
    test_labels_list = t_test_labels_list.tolist()      
    
    avg_loss = sum(test_loss_list)/len(test_loss_list)

    return avg_loss, [test_predicted_list, test_ground_list, test_labels_list]

# %%
from evaluate import (
    get_err_scores,
    get_best_performance_data,
    get_val_performance_data,
    get_full_err_scores,
)
def get_score(test_result, val_result):

    feature_num = len(test_result[0][0])
    np_test_result = np.array(test_result)
    np_val_result = np.array(val_result)

    test_labels = np_test_result[2, :, 0].tolist()

    test_scores, normal_scores = get_full_err_scores(test_result, val_result)

    top1_best_info = get_best_performance_data(test_scores, test_labels, topk=1)
    top1_val_info = get_val_performance_data(
        test_scores, normal_scores, test_labels, topk=1
    )

    print("=========================** Result **============================\n")

    info = None
    #if self.env_config["report"] == "best":
    info = top1_best_info
#     elif self.env_config["report"] == "val":
#         info = top1_val_info

    print(f"F1 score: {info[0]}")
    print(f"precision: {info[1]}")
    print(f"recall: {info[2]}\n")

# %%
model.train()
train_loss = []
model_save_path = get_save_path()[0]
for i_epoch in range(configs["epoch"]):
    acu_loss = 0
    for x, labels, attack_labels in train_dataloader:
        x, labels = [item.float().to(configs['device']) for item in [x, labels]]
        optimizer.zero_grad()
        out = model(x).float().to(configs['device'])
        loss = F.mse_loss(out, labels, reduction="mean")
        loss.backward()
        optimizer.step()
        train_loss.append(loss.item())
        acu_loss += loss.item()
        print(
            "epoch ({} / {}) (Loss:{:.8f}, ACU_loss:{:.8f})".format(
                i_epoch, configs["epoch"], acu_loss / len(train_dataloader), acu_loss
            ),
            flush=True,
        )

        # use val dataset to judge
        if val_dataloader is not None:

            val_loss, val_result = test(model, val_dataloader)

            if val_loss < min_loss:
                torch.save(model.state_dict(), model_save_path)

                min_loss = val_loss
                stop_improve_count = 0
            else:
                stop_improve_count += 1

            if stop_improve_count >= 15:
                break

        else:
            if acu_loss < min_loss:
                torch.save(model.state_dict(), save_path)
                min_loss = acu_loss
    model.load_state_dict(torch.load(model_save_path))
    best_model =model.to("cpu")

    _, test_result = test(best_model, test_dataloader)
    _, val_result = test(best_model, val_dataloader)

    get_score(test_result, val_result)
# Out:
# epoch (0 / 10) (Loss:0.24308949, ACU_loss:2.43089485)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (0 / 10) (Loss:0.32112331, ACU_loss:3.21123314)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (0 / 10) (Loss:0.40043521, ACU_loss:4.00435209)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (0 / 10) (Loss:0.48008639, ACU_loss:4.80086386)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (0 / 10) (Loss:0.55989443, ACU_loss:5.59894431)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (0 / 10) (Loss:0.63919410, ACU_loss:6.39194101)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (0 / 10) (Loss:0.71543733, ACU_loss:7.15437335)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (0 / 10) (Loss:0.79193571, ACU_loss:7.91935712)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (0 / 10) (Loss:0.86837374, ACU_loss:8.68373740)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (0 / 10) (Loss:0.94598592, ACU_loss:9.45985919)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# =========================** Result **============================
#
# F1 score: 0.8690265486725663
# precision: 0.768668407310705
# recall: 0.9986431478968792
#
# epoch (1 / 10) (Loss:0.07853161, ACU_loss:0.78531605)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (1 / 10) (Loss:0.15385519, ACU_loss:1.53855193)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (1 / 10) (Loss:0.22983559, ACU_loss:2.29835594)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (1 / 10) (Loss:0.30347472, ACU_loss:3.03474724)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (1 / 10) (Loss:0.38091633, ACU_loss:3.80916333)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (1 / 10) (Loss:0.45875604, ACU_loss:4.58756042)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (1 / 10) (Loss:0.53352942, ACU_loss:5.33529425)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (1 / 10) (Loss:0.60553115, ACU_loss:6.05531150)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (1 / 10) (Loss:0.68266734, ACU_loss:6.82667339)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (1 / 10) (Loss:0.75733192, ACU_loss:7.57331920)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# =========================** Result **============================
#
# F1 score: 0.8690265486725663
# precision: 0.768668407310705
# recall: 0.9986431478968792
#
# epoch (2 / 10) (Loss:0.07505003, ACU_loss:0.75050026)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (2 / 10) (Loss:0.14903120, ACU_loss:1.49031198)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (2 / 10) (Loss:0.22118422, ACU_loss:2.21184224)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (2 / 10) (Loss:0.29418380, ACU_loss:2.94183797)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (2 / 10) (Loss:0.36760726, ACU_loss:3.67607260)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (2 / 10) (Loss:0.43877571, ACU_loss:4.38775706)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (2 / 10) (Loss:0.50950434, ACU_loss:5.09504336)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (2 / 10) (Loss:0.58388263, ACU_loss:5.83882630)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (2 / 10) (Loss:0.65981768, ACU_loss:6.59817678)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (2 / 10) (Loss:0.73209395, ACU_loss:7.32093954)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# =========================** Result **============================
#
# F1 score: 0.8690265486725663
# precision: 0.768668407310705
# recall: 0.9986431478968792
#
# epoch (3 / 10) (Loss:0.07165517, ACU_loss:0.71655172)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (3 / 10) (Loss:0.14055177, ACU_loss:1.40551770)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (3 / 10) (Loss:0.21097670, ACU_loss:2.10976696)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (3 / 10) (Loss:0.28467895, ACU_loss:2.84678948)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (3 / 10) (Loss:0.35626421, ACU_loss:3.56264210)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (3 / 10) (Loss:0.42752656, ACU_loss:4.27526563)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (3 / 10) (Loss:0.49805835, ACU_loss:4.98058355)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (3 / 10) (Loss:0.56756577, ACU_loss:5.67565769)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (3 / 10) (Loss:0.63958453, ACU_loss:6.39584529)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (3 / 10) (Loss:0.71106036, ACU_loss:7.11060357)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# =========================** Result **============================
#
# F1 score: 0.8690265486725663
# precision: 0.768668407310705
# recall: 0.9986431478968792
#
# epoch (4 / 10) (Loss:0.07144544, ACU_loss:0.71445441)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (4 / 10) (Loss:0.14354228, ACU_loss:1.43542278)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (4 / 10) (Loss:0.21324198, ACU_loss:2.13241982)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (4 / 10) (Loss:0.28397418, ACU_loss:2.83974177)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (4 / 10) (Loss:0.35500588, ACU_loss:3.55005884)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (4 / 10) (Loss:0.42534425, ACU_loss:4.25344247)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (4 / 10) (Loss:0.49724433, ACU_loss:4.97244334)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (4 / 10) (Loss:0.56436392, ACU_loss:5.64363921)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (4 / 10) (Loss:0.63331847, ACU_loss:6.33318466)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (4 / 10) (Loss:0.70172067, ACU_loss:7.01720667)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# =========================** Result **============================
#
# F1 score: 0.8690265486725663
# precision: 0.768668407310705
# recall: 0.9986431478968792
#
# epoch (5 / 10) (Loss:0.06942538, ACU_loss:0.69425380)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (5 / 10) (Loss:0.13851062, ACU_loss:1.38510621)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (5 / 10) (Loss:0.20983160, ACU_loss:2.09831601)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (5 / 10) (Loss:0.27951666, ACU_loss:2.79516655)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (5 / 10) (Loss:0.34940445, ACU_loss:3.49404454)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (5 / 10) (Loss:0.41786419, ACU_loss:4.17864186)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (5 / 10) (Loss:0.48823062, ACU_loss:4.88230616)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (5 / 10) (Loss:0.55684606, ACU_loss:5.56846058)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (5 / 10) (Loss:0.62628451, ACU_loss:6.26284510)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (5 / 10) (Loss:0.69290953, ACU_loss:6.92909533)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# =========================** Result **============================
#
# F1 score: 0.8690265486725663
# precision: 0.768668407310705
# recall: 0.9986431478968792
#
# epoch (6 / 10) (Loss:0.06749592, ACU_loss:0.67495924)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (6 / 10) (Loss:0.13683607, ACU_loss:1.36836070)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (6 / 10) (Loss:0.20467847, ACU_loss:2.04678470)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (6 / 10) (Loss:0.27555395, ACU_loss:2.75553954)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (6 / 10) (Loss:0.34266394, ACU_loss:3.42663944)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (6 / 10) (Loss:0.41096690, ACU_loss:4.10966897)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (6 / 10) (Loss:0.48313350, ACU_loss:4.83133501)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (6 / 10) (Loss:0.55160252, ACU_loss:5.51602525)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (6 / 10) (Loss:0.62126306, ACU_loss:6.21263057)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (6 / 10) (Loss:0.68763121, ACU_loss:6.87631214)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# =========================** Result **============================
#
# F1 score: 0.8690265486725663
# precision: 0.768668407310705
# recall: 0.9986431478968792
#
# epoch (7 / 10) (Loss:0.06626404, ACU_loss:0.66264039)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (7 / 10) (Loss:0.13444974, ACU_loss:1.34449738)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (7 / 10) (Loss:0.20350962, ACU_loss:2.03509617)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (7 / 10) (Loss:0.27275275, ACU_loss:2.72752750)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (7 / 10) (Loss:0.34098043, ACU_loss:3.40980434)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (7 / 10) (Loss:0.41161678, ACU_loss:4.11616778)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (7 / 10) (Loss:0.47852438, ACU_loss:4.78524381)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (7 / 10) (Loss:0.54516867, ACU_loss:5.45168674)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (7 / 10) (Loss:0.61255900, ACU_loss:6.12558997)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (7 / 10) (Loss:0.68153188, ACU_loss:6.81531876)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# =========================** Result **============================
#
# F1 score: 0.8690265486725663
# precision: 0.768668407310705
# recall: 0.9986431478968792
#
# epoch (8 / 10) (Loss:0.06729985, ACU_loss:0.67299855)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (8 / 10) (Loss:0.13297845, ACU_loss:1.32978451)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (8 / 10) (Loss:0.20145758, ACU_loss:2.01457584)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (8 / 10) (Loss:0.26895124, ACU_loss:2.68951243)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (8 / 10) (Loss:0.33647294, ACU_loss:3.36472940)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (8 / 10) (Loss:0.40477151, ACU_loss:4.04771513)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (8 / 10) (Loss:0.47319435, ACU_loss:4.73194355)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (8 / 10) (Loss:0.54245762, ACU_loss:5.42457622)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (8 / 10) (Loss:0.61134864, ACU_loss:6.11348641)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (8 / 10) (Loss:0.67797000, ACU_loss:6.77969998)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# =========================** Result **============================
#
# F1 score: 0.8690265486725663
# precision: 0.768668407310705
# recall: 0.9986431478968792
#
# epoch (9 / 10) (Loss:0.06730783, ACU_loss:0.67307830)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (9 / 10) (Loss:0.13411061, ACU_loss:1.34110606)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (9 / 10) (Loss:0.20079824, ACU_loss:2.00798237)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (9 / 10) (Loss:0.26710659, ACU_loss:2.67106593)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (9 / 10) (Loss:0.33237083, ACU_loss:3.32370830)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (9 / 10) (Loss:0.39760411, ACU_loss:3.97604114)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (9 / 10) (Loss:0.46742562, ACU_loss:4.67425621)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (9 / 10) (Loss:0.53357573, ACU_loss:5.33575726)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (9 / 10) (Loss:0.59892743, ACU_loss:5.98927426)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# epoch (9 / 10) (Loss:0.66266586, ACU_loss:6.62665856)
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# torch.Size([128, 27]) torch.Size([128, 27]) torch.Size([128, 27, 3])
# =========================** Result **============================
#
# F1 score: 0.8690265486725663
# precision: 0.768668407310705
# recall: 0.9986431478968792
